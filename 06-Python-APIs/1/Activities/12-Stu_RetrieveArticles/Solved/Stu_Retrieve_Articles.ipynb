# %%
# Dependencies
import requests
from config import api_key
import time

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
query = "obama"

# Search for articles published between a begin and end date
begin_date = "20160101"
end_date = "20160130"

query_url ="https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=8dc500a25dad40edb659702411b52ca5&q=obama&begin_date=20160101&end_date=20160130"

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles_list = [article for article in articles["response"]["docs"]]

# for article in articles_list:
#     print f'A snippet from the article: {article["snippet"]}'

# %%
articles['response']['docs']
# Out:
# [{u'_id': u'568efce138f0d8580b9abac2',
#   u'blog': {},
#   u'byline': {u'organization': None,
#    u'original': u'By BARACK OBAMA',
#    u'person': [{u'firstname': u'Barack',
#      u'lastname': u'OBAMA',
#      u'middlename': None,
#      u'organization': u'',
#      u'qualifier': None,
#      u'rank': 1,
#      u'role': u'reported',
#      u'title': None}]},
#   u'document_type': u'article',
#   u'headline': {u'content_kicker': u'Op-Ed Contributor',
#    u'kicker': u'Op-Ed Contributor',
#    u'main': u'Barack Obama: Guns Are Our Shared Responsibility',
#    u'name': None,
#    u'print_headline': u'Our Shared Responsibility',
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': u'N',
#     u'name': u'subject',
#     u'rank': 1,
#     u'value': u'Gun Control'},
#    {u'major': u'N',
#     u'name': u'subject',
#     u'rank': 2,
#     u'value': u'Executive Orders and Memorandums'},
#    {u'major': u'N',
#     u'name': u'subject',
#     u'rank': 3,
#     u'value': u'United States Politics and Government'},
#    {u'major': u'N', u'name': u'subject', u'rank': 4, u'value': u'Firearms'}],
#   u'multimedia': [{u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 374,
#     u'legacy': {u'xlarge': u'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-articleLarge.jpg',
#      u'xlargeheight': 374,
#      u'xlargewidth': 600},
#     u'rank': 0,
#     u'subType': u'xlarge',
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-articleLarge.jpg',
#     u'width': 600},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 126,
#     u'legacy': {u'wide': u'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbWide.jpg',
#      u'wideheight': 126,
#      u'widewidth': 190},
#     u'rank': 0,
#     u'subType': u'wide',
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbWide.jpg',
#     u'width': 190},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbStandard.jpg',
#      u'thumbnailheight': 75,
#      u'thumbnailwidth': 75},
#     u'rank': 0,
#     u'subType': u'thumbnail',
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'OpEd',
#   u'print_page': u'23',
#   u'pub_date': u'2016-01-08T00:03:35+0000',
#   u'score': 0.0056717647,
#   u'snippet': u'I will not campaign for, vote for or support any candidate, even in my own party, who does not support common-sense gun reform.',
#   u'source': u'The New York Times',
#   u'type_of_material': u'Op-Ed',
#   u'uri': u'nyt://article/a7894d4a-24ca-5a9e-abca-616317c8b656',
#   u'web_url': u'https://www.nytimes.com/2016/01/08/opinion/president-barack-obama-guns-are-our-shared-responsibility.html',
#   u'word_count': 858},
#  {u'_id': u'568f12b038f0d8580b9abb00',
#   u'blog': {},
#   u'byline': {u'organization': None,
#    u'original': u'Por BARACK OBAMA',
#    u'person': [{u'firstname': u'Por',
#      u'lastname': u'OBAMA',
#      u'middlename': u'Barack',
#      u'organization': u'',
#      u'qualifier': None,
#      u'rank': 1,
#      u'role': u'reported',
#      u'title': None}]},
#   u'document_type': u'article',
#   u'headline': {u'content_kicker': u'Am\xe9rica ',
#    u'kicker': None,
#    u'main': u'Barack Obama: Las armas de fuego son responsabilidad de todos',
#    u'name': None,
#    u'print_headline': None,
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': None,
#     u'name': u'subject',
#     u'rank': 1,
#     u'value': u'Gun Control'},
#    {u'major': None,
#     u'name': u'subject',
#     u'rank': 2,
#     u'value': u'Executive Orders and Memorandums'},
#    {u'major': None,
#     u'name': u'subject',
#     u'rank': 3,
#     u'value': u'United States Politics and Government'}],
#   u'multimedia': [{u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 126,
#     u'legacy': {u'wide': u'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'rank': 0,
#     u'subType': u'wide',
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbWide.jpg',
#     u'width': 190},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 412,
#     u'legacy': {u'xlarge': u'images/2016/01/08/opinion/08guns-copy-ES/08guns-articleLarge.jpg',
#      u'xlargeheight': u'412',
#      u'xlargewidth': u'600'},
#     u'rank': 0,
#     u'subType': u'xlarge',
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2016/01/08/opinion/08guns-copy-ES/08guns-articleLarge.jpg',
#     u'width': 600},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'rank': 0,
#     u'subType': u'thumbnail',
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'OpEd',
#   u'pub_date': u'2016-01-08T00:00:00Z',
#   u'score': 0.0053227856,
#   u'section_name': u'Am\xe9rica',
#   u'snippet': u'Todos \u2013gobierno, sector privado y los ciudadanos\u2013 debemos hacer un frente com\xfan para acabar con esta violencia sin sentido.',
#   u'source': u'The New York Times',
#   u'type_of_material': u'Op-Ed',
#   u'web_url': u'https://www.nytimes.com/2016/01/08/universal/es/president-barack-obama-guns-are-our-shared-responsibility.html',
#   u'word_count': 994},
#  {u'_id': u'56a5db0238f0d81529067d20',
#   u'blog': {},
#   u'byline': {u'organization': None,
#    u'original': u'By DAVID AXELROD',
#    u'person': [{u'firstname': u'David',
#      u'lastname': u'AXELROD',
#      u'middlename': None,
#      u'organization': u'',
#      u'qualifier': None,
#      u'rank': 1,
#      u'role': u'reported',
#      u'title': None}]},
#   u'document_type': u'article',
#   u'headline': {u'content_kicker': u'Op-Ed Contributor',
#    u'kicker': u'Op-Ed Contributor',
#    u'main': u'The Obama Theory of Trump',
#    u'name': None,
#    u'print_headline': u'The Obama Theory of Trump',
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': u'N',
#     u'name': u'subject',
#     u'rank': 1,
#     u'value': u'Presidential Election of 2016'},
#    {u'major': u'N',
#     u'name': u'persons',
#     u'rank': 2,
#     u'value': u'Trump, Donald J'},
#    {u'major': u'N',
#     u'name': u'persons',
#     u'rank': 3,
#     u'value': u'Obama, Barack'},
#    {u'major': u'N',
#     u'name': u'subject',
#     u'rank': 4,
#     u'value': u'United States Politics and Government'},
#    {u'major': u'N',
#     u'name': u'subject',
#     u'rank': 5,
#     u'value': u'Polls and Public Opinion'},
#    {u'major': u'N',
#     u'name': u'subject',
#     u'rank': 6,
#     u'value': u'Voting and Voters'},
#    {u'major': u'N',
#     u'name': u'organizations',
#     u'rank': 7,
#     u'value': u'Republican Party'}],
#   u'multimedia': [{u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 393,
#     u'legacy': {u'xlarge': u'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-articleLarge.jpg',
#      u'xlargeheight': 393,
#      u'xlargewidth': 600},
#     u'rank': 0,
#     u'subType': u'xlarge',
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-articleLarge.jpg',
#     u'width': 600},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 126,
#     u'legacy': {u'wide': u'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbWide.jpg',
#      u'wideheight': 126,
#      u'widewidth': 190},
#     u'rank': 0,
#     u'subType': u'wide',
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbWide.jpg',
#     u'width': 190},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbStandard.jpg',
#      u'thumbnailheight': 75,
#      u'thumbnailwidth': 75},
#     u'rank': 0,
#     u'subType': u'thumbnail',
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'OpEd',
#   u'print_page': u'21',
#   u'pub_date': u'2016-01-25T08:21:17+0000',
#   u'score': 0.004517503,
#   u'section_name': u'Campaign Stops',
#   u'snippet': u'In presidential elections, opposites attract.',
#   u'source': u'The New York Times',
#   u'type_of_material': u'Op-Ed',
#   u'uri': u'nyt://article/ae224f9a-e4c5-53b7-9681-905a15bbc393',
#   u'web_url': u'https://www.nytimes.com/2016/01/25/opinion/campaign-stops/the-obama-theory-of-trump.html',
#   u'word_count': 1078},
#  {u'_id': u'569365fc38f0d801cf86fb39',
#   u'blog': {},
#   u'byline': {u'organization': None,
#    u'original': u'By PAUL KRUGMAN',
#    u'person': [{u'firstname': u'Paul',
#      u'lastname': u'KRUGMAN',
#      u'middlename': None,
#      u'organization': u'',
#      u'qualifier': None,
#      u'rank': 1,
#      u'role': u'reported',
#      u'title': None}]},
#   u'document_type': u'article',
#   u'headline': {u'content_kicker': u'Op-Ed Columnist',
#    u'kicker': u'Op-Ed Columnist',
#    u'main': u'The Obama Boom',
#    u'name': None,
#    u'print_headline': u'The  Obama  Boom',
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': u'N',
#     u'name': u'subject',
#     u'rank': 1,
#     u'value': u'United States Economy'},
#    {u'major': u'N',
#     u'name': u'persons',
#     u'rank': 2,
#     u'value': u'Obama, Barack'},
#    {u'major': u'N',
#     u'name': u'subject',
#     u'rank': 3,
#     u'value': u'Labor and Jobs'},
#    {u'major': u'N',
#     u'name': u'subject',
#     u'rank': 4,
#     u'value': u'United States Politics and Government'}],
#   u'multimedia': [{u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 400,
#     u'legacy': {u'xlarge': u'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-articleLarge.jpg',
#      u'xlargeheight': 400,
#      u'xlargewidth': 600},
#     u'rank': 0,
#     u'subType': u'xlarge',
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-articleLarge.jpg',
#     u'width': 600},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 126,
#     u'legacy': {u'wide': u'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbWide.jpg',
#      u'wideheight': 126,
#      u'widewidth': 190},
#     u'rank': 0,
#     u'subType': u'wide',
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbWide.jpg',
#     u'width': 190},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbStandard.jpg',
#      u'thumbnailheight': 75,
#      u'thumbnailwidth': 75},
#     u'rank': 0,
#     u'subType': u'thumbnail',
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'OpEd',
#   u'print_page': u'23',
#   u'pub_date': u'2016-01-11T08:21:05+0000',
#   u'score': 0.0016328972,
#   u'snippet': u'Dire warnings from Republicans about the effect of President Obama\u2019s policies on employment have simply not come true.',
#   u'source': u'The New York Times',
#   u'type_of_material': u'Op-Ed',
#   u'uri': u'nyt://article/96cc9aff-1806-51ba-8dee-9fff728009f2',
#   u'web_url': u'https://www.nytimes.com/2016/01/11/opinion/the-obama-boom.html',
#   u'word_count': 803},
#  {u'_id': u'56981f5238f0d8108a7eb756',
#   u'blog': {},
#   u'byline': {u'organization': u'THE ASSOCIATED PRESS',
#    u'original': u'By THE ASSOCIATED PRESS',
#    u'person': []},
#   u'document_type': u'multimedia',
#   u'headline': {u'content_kicker': None,
#    u'kicker': None,
#    u'main': u'Obama On the Road',
#    u'name': None,
#    u'print_headline': None,
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': None,
#     u'name': u'persons',
#     u'rank': 1,
#     u'value': u'Obama, Barack'}],
#   u'multimedia': [{u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 126,
#     u'legacy': {u'wide': u'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbWide-v2.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'rank': 0,
#     u'subType': u'wide',
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbWide-v2.jpg',
#     u'width': 190},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 337,
#     u'legacy': {u'xlarge': u'images/2016/01/15/us/15obama1_hp/15obama1_hp-articleLarge-v2.jpg',
#      u'xlargeheight': u'337',
#      u'xlargewidth': u'600'},
#     u'rank': 0,
#     u'subType': u'xlarge',
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2016/01/15/us/15obama1_hp/15obama1_hp-articleLarge-v2.jpg',
#     u'width': 600},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'rank': 0,
#     u'subType': u'thumbnail',
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'U.S.',
#   u'pub_date': u'2016-01-14T16:44:35Z',
#   u'score': 0.0015332106,
#   u'snippet': u'Highlights from President Obama\u2019s remarks at a town-hall style meeting in Baton Rouge, La, on Thursday.',
#   u'source': u'AP',
#   u'type_of_material': u'Video',
#   u'web_url': u'https://www.nytimes.com/video/us/100000004145097/obama-on-the-road.html',
#   u'word_count': 16},
#  {u'_id': u'5697db3738f0d8108a7eb67d',
#   u'abstract': u'\u201cLet me tell you, there are three things that are certain in life: death, taxes, and Michelle is not running for president.\u201d \u2014 President Obama',
#   u'blog': {},
#   u'byline': {u'organization': None,
#    u'original': u'By FIRST DRAFT',
#    u'person': [{u'firstname': u'First',
#      u'lastname': u'DRAFT',
#      u'middlename': None,
#      u'organization': u'',
#      u'qualifier': None,
#      u'rank': 1,
#      u'role': u'reported',
#      u'title': None}]},
#   u'document_type': u'blogpost',
#   u'headline': {u'content_kicker': None,
#    u'kicker': u'First Draft',
#    u'main': u'Verbatim: Barack Obama on Michelle Obama&#8217;s Presidential Ambitions',
#    u'name': None,
#    u'print_headline': None,
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': None,
#     u'name': u'persons',
#     u'rank': 1,
#     u'value': u'Obama, Barack'},
#    {u'major': None,
#     u'name': u'persons',
#     u'rank': 2,
#     u'value': u'Obama, Michelle'},
#    {u'major': None,
#     u'name': u'glocations',
#     u'rank': 1,
#     u'value': u'Baton Rouge (La)'}],
#   u'multimedia': [],
#   u'news_desk': u'Politics',
#   u'pub_date': u'2016-01-14T12:28:54Z',
#   u'score': 0.0013566227,
#   u'section_name': u'Politics',
#   u'snippet': u'\u201cLet me tell you, there are three things that are certain in life: death, taxes, and Michelle is not running for president.\u201d \u2014 President Obama',
#   u'source': u'The New York Times',
#   u'type_of_material': u'Blog',
#   u'web_url': u'https://www.nytimes.com/politics/first-draft/2016/01/14/verbatim-barack-obama-on-michelle-obamas-presidential-ambitions/',
#   u'word_count': 74},
#  {u'_id': u'56a009a338f0d80627b20b46',
#   u'blog': {},
#   u'byline': {u'organization': u'REUTERS',
#    u'original': u'By REUTERS',
#    u'person': []},
#   u'document_type': u'multimedia',
#   u'headline': {u'content_kicker': None,
#    u'kicker': None,
#    u'main': u'Obama on Flint Water Crisis',
#    u'name': None,
#    u'print_headline': None,
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': None,
#     u'name': u'persons',
#     u'rank': 1,
#     u'value': u'Obama, Barack'},
#    {u'major': None,
#     u'name': u'glocations',
#     u'rank': 2,
#     u'value': u'Flint (Mich)'},
#    {u'major': None,
#     u'name': u'subject',
#     u'rank': 3,
#     u'value': u'Water Pollution'},
#    {u'major': None, u'name': u'subject', u'rank': 4, u'value': u'Lead'}],
#   u'multimedia': [{u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 126,
#     u'legacy': {u'wide': u'images/2016/01/21/us/21obama-vid/21obama-vid-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'rank': 0,
#     u'subType': u'wide',
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2016/01/21/us/21obama-vid/21obama-vid-thumbWide.jpg',
#     u'width': 190},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 400,
#     u'legacy': {u'xlarge': u'images/2016/01/21/us/21obama-vid/21obama-vid-articleLarge.jpg',
#      u'xlargeheight': u'400',
#      u'xlargewidth': u'600'},
#     u'rank': 0,
#     u'subType': u'xlarge',
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2016/01/21/us/21obama-vid/21obama-vid-articleLarge.jpg',
#     u'width': 600},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2016/01/21/us/21obama-vid/21obama-vid-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'rank': 0,
#     u'subType': u'thumbnail',
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2016/01/21/us/21obama-vid/21obama-vid-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'U.S.',
#   u'pub_date': u'2016-01-20T17:26:27Z',
#   u'score': 0.0013341766,
#   u'snippet': u'President Obama, speaking at the North American International Auto Show in Detroit, expressed sympathy and concern for residents of Flint, Mich., where there has been lead contamination in the drinking water.',
#   u'source': u'Reuters',
#   u'type_of_material': u'Video',
#   u'web_url': u'https://www.nytimes.com/video/us/100000004157088/obama-on-flint-water-crisis.html',
#   u'word_count': 31},
#  {u'_id': u'569bcd3538f0d821e003cd00',
#   u'blog': {},
#   u'byline': {u'organization': u'THE ASSOCIATED PRESS',
#    u'original': u'By THE ASSOCIATED PRESS',
#    u'person': []},
#   u'document_type': u'multimedia',
#   u'headline': {u'content_kicker': None,
#    u'kicker': None,
#    u'main': u'Obama Celebrates Deal With Iran',
#    u'name': None,
#    u'print_headline': None,
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': None,
#     u'name': u'subject',
#     u'rank': 1,
#     u'value': u'United States Politics and Government'},
#    {u'major': None,
#     u'name': u'persons',
#     u'rank': 2,
#     u'value': u'Obama, Barack'},
#    {u'major': None, u'name': u'glocations', u'rank': 3, u'value': u'Iran'},
#    {u'major': None,
#     u'name': u'subject',
#     u'rank': 4,
#     u'value': u'Prisons and Prisoners'}],
#   u'multimedia': [{u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 126,
#     u'legacy': {u'wide': u'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'rank': 0,
#     u'subType': u'wide',
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-thumbWide.jpg',
#     u'width': 190},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 400,
#     u'legacy': {u'xlarge': u'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-articleLarge.jpg',
#      u'xlargeheight': u'400',
#      u'xlargewidth': u'600'},
#     u'rank': 0,
#     u'subType': u'xlarge',
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-articleLarge.jpg',
#     u'width': 600},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'rank': 0,
#     u'subType': u'thumbnail',
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'World / Americas',
#   u'pub_date': u'2016-01-17T12:19:29Z',
#   u'score': 0.0013160824,
#   u'section_name': u'Americas',
#   u'snippet': u'President Obama expressed relief and happiness that several Americans who had been detained in Iran were returning home after the completion of a nuclear agreement with Tehran.',
#   u'source': u'Reuters',
#   u'type_of_material': u'Video',
#   u'web_url': u'https://www.nytimes.com/video/world/americas/100000004150287/obama-celebrates-deal-with-iran.html',
#   u'word_count': 27},
#  {u'_id': u'5695bff338f0d83e7cfe0459',
#   u'blog': {},
#   u'byline': {u'organization': u'THE ASSOCIATED PRESS',
#    u'original': u'By THE ASSOCIATED PRESS',
#    u'person': []},
#   u'document_type': u'multimedia',
#   u'headline': {u'content_kicker': None,
#    u'kicker': None,
#    u'main': u'Obama on Terrorism',
#    u'name': None,
#    u'print_headline': None,
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': None,
#     u'name': u'subject',
#     u'rank': 1,
#     u'value': u'State of the Union Message (US)'},
#    {u'major': None,
#     u'name': u'persons',
#     u'rank': 2,
#     u'value': u'Obama, Barack'},
#    {u'major': None, u'name': u'subject', u'rank': 3, u'value': u'Terrorism'}],
#   u'multimedia': [{u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 126,
#     u'legacy': {u'wide': u'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'rank': 0,
#     u'subType': u'wide',
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-thumbWide.jpg',
#     u'width': 190},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 400,
#     u'legacy': {u'xlarge': u'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-articleLarge.jpg',
#      u'xlargeheight': u'400',
#      u'xlargewidth': u'600'},
#     u'rank': 0,
#     u'subType': u'xlarge',
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-articleLarge.jpg',
#     u'width': 600},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'rank': 0,
#     u'subType': u'thumbnail',
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'U.S. / Politics',
#   u'pub_date': u'2016-01-12T22:09:23Z',
#   u'score': 0.0012890734,
#   u'section_name': u'Politics',
#   u'snippet': u'The president delivered his final State of the Union address on Tuesday and discussed the threat posed by the Islamic State.',
#   u'source': u'AP',
#   u'type_of_material': u'Video',
#   u'web_url': u'https://www.nytimes.com/video/us/politics/100000004141206/obama-on-terrorism.html',
#   u'word_count': 21},
#  {u'_id': u'5695b6b738f0d83e7cfe0440',
#   u'blog': {},
#   u'byline': {u'organization': u'THE ASSOCIATED PRESS',
#    u'original': u'By THE ASSOCIATED PRESS',
#    u'person': []},
#   u'document_type': u'multimedia',
#   u'headline': {u'content_kicker': None,
#    u'kicker': None,
#    u'main': u'Obama on Economy',
#    u'name': None,
#    u'print_headline': None,
#    u'seo': None,
#    u'sub': None},
#   u'keywords': [{u'major': None,
#     u'name': u'persons',
#     u'rank': 1,
#     u'value': u'Obama, Barack'},
#    {u'major': None,
#     u'name': u'subject',
#     u'rank': 2,
#     u'value': u'State of the Union Message (US)'},
#    {u'major': None,
#     u'name': u'subject',
#     u'rank': 3,
#     u'value': u'United States Politics and Government'}],
#   u'multimedia': [{u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 126,
#     u'legacy': {u'wide': u'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'rank': 0,
#     u'subType': u'wide',
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-thumbWide.jpg',
#     u'width': 190},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 400,
#     u'legacy': {u'xlarge': u'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-articleLarge.jpg',
#      u'xlargeheight': u'400',
#      u'xlargewidth': u'600'},
#     u'rank': 0,
#     u'subType': u'xlarge',
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-articleLarge.jpg',
#     u'width': 600},
#    {u'caption': None,
#     u'credit': None,
#     u'crop_name': None,
#     u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'rank': 0,
#     u'subType': u'thumbnail',
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'U.S. / Politics',
#   u'pub_date': u'2016-01-12T21:30:00Z',
#   u'score': 0.001288623,
#   u'section_name': u'Politics',
#   u'snippet': u'The president delivered his final State of the Union address on Tuesday and discussed economic growth.',
#   u'source': u'AP',
#   u'type_of_material': u'Video',
#   u'web_url': u'https://www.nytimes.com/video/us/politics/100000004141131/obama-on-economy.html',
#   u'word_count': 16}]

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# Emply list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 3):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    # loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)
